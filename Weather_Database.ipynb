# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/ramonmanrique/opt/anaconda3/lib/python3.9/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/ramonmanrique/opt/anaconda3/lib/python3.9/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao filipe
# Processing Record 2 of Set 1 | kantilo
# Processing Record 3 of Set 1 | san cristobal
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | paamiut
# Processing Record 6 of Set 1 | eganville
# Processing Record 7 of Set 1 | rio gallegos
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | sobolevo
# Processing Record 12 of Set 1 | clarence town
# Processing Record 13 of Set 1 | lavrentiya
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | antofagasta
# Processing Record 21 of Set 1 | buta
# Processing Record 22 of Set 1 | saint george
# Processing Record 23 of Set 1 | oleksandrivka
# Processing Record 24 of Set 1 | lumeje
# Processing Record 25 of Set 1 | yarada
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | sovetskiy
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | brae
# Processing Record 33 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 1 | lanzhou
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | ariquemes
# Processing Record 38 of Set 1 | jieshi
# Processing Record 39 of Set 1 | muros
# Processing Record 40 of Set 1 | ust-nera
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | kutum
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | blackwater
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | provideniya
# Processing Record 48 of Set 1 | zavitinsk
# Processing Record 49 of Set 1 | progreso
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | egvekinot
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | sorland
# Processing Record 5 of Set 2 | novokruchininskiy
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | vila franca do campo
# Processing Record 8 of Set 2 | san felipe
# Processing Record 9 of Set 2 | havre-saint-pierre
# Processing Record 10 of Set 2 | sur
# Processing Record 11 of Set 2 | ust-maya
# Processing Record 12 of Set 2 | nevers
# Processing Record 13 of Set 2 | rocha
# Processing Record 14 of Set 2 | coquimbo
# Processing Record 15 of Set 2 | hervey bay
# Processing Record 16 of Set 2 | tateyama
# Processing Record 17 of Set 2 | port macquarie
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | lompoc
# Processing Record 20 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 2 | palm valley
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | kudahuvadhoo
# Processing Record 24 of Set 2 | henties bay
# Processing Record 25 of Set 2 | gravdal
# Processing Record 26 of Set 2 | yairipok
# Processing Record 27 of Set 2 | castro
# Processing Record 28 of Set 2 | pevek
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | mulchen
# Processing Record 31 of Set 2 | state college
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | batagay-alyta
# Processing Record 35 of Set 2 | bubaque
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | tilichiki
# Processing Record 38 of Set 2 | pangai
# Processing Record 39 of Set 2 | iqaluit
# Processing Record 40 of Set 2 | dolores
# Processing Record 41 of Set 2 | mount isa
# Processing Record 42 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 2 | mar del plata
# Processing Record 44 of Set 2 | omaruru
# Processing Record 45 of Set 2 | nadadores
# Processing Record 46 of Set 2 | kavaratti
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 2 | constitucion
# Processing Record 50 of Set 2 | coihaique
# Processing Record 1 of Set 3 | east wenatchee bench
# Processing Record 2 of Set 3 | mareeba
# Processing Record 3 of Set 3 | buala
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | olafsvik
# Processing Record 6 of Set 3 | tessalit
# Processing Record 7 of Set 3 | terney
# Processing Record 8 of Set 3 | dandong
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 3 | am timan
# Processing Record 13 of Set 3 | gimli
# Processing Record 14 of Set 3 | kuytun
# Processing Record 15 of Set 3 | san luis
# Processing Record 16 of Set 3 | chicama
# Processing Record 17 of Set 3 | gat
# Processing Record 18 of Set 3 | beloha
# Processing Record 19 of Set 3 | lorengau
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | mana
# Processing Record 22 of Set 3 | college
# Processing Record 23 of Set 3 | mbandaka
# Processing Record 24 of Set 3 | tuatapere
# Processing Record 25 of Set 3 | maldonado
# Processing Record 26 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 3 | kaitangata
# Processing Record 28 of Set 3 | gerede
# Processing Record 29 of Set 3 | port elizabeth
# Processing Record 30 of Set 3 | amapa
# Processing Record 31 of Set 3 | norman wells
# Processing Record 32 of Set 3 | dawson creek
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | nuuk
# Processing Record 35 of Set 3 | touros
# Processing Record 36 of Set 3 | tagab
# Processing Record 37 of Set 3 | ribeira grande
# Processing Record 38 of Set 3 | north bend
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 3 | katobu
# Processing Record 42 of Set 3 | port hedland
# Processing Record 43 of Set 3 | planadas
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | atuona
# Processing Record 46 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 3 | saskylakh
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | kodiak
# Processing Record 50 of Set 3 | cherskiy
# Processing Record 1 of Set 4 | broome
# Processing Record 2 of Set 4 | sambava
# Processing Record 3 of Set 4 | dodge city
# Processing Record 4 of Set 4 | port lincoln
# Processing Record 5 of Set 4 | maumere
# Processing Record 6 of Set 4 | tasiilaq
# Processing Record 7 of Set 4 | mitchell
# Processing Record 8 of Set 4 | ahuimanu
# Processing Record 9 of Set 4 | diego de almagro
# Processing Record 10 of Set 4 | stephenville
# Processing Record 11 of Set 4 | san patricio
# Processing Record 12 of Set 4 | vila velha
# Processing Record 13 of Set 4 | gornopravdinsk
# Processing Record 14 of Set 4 | namatanai
# Processing Record 15 of Set 4 | gwadar
# Processing Record 16 of Set 4 | hovd
# Processing Record 17 of Set 4 | victoria
# Processing Record 18 of Set 4 | kununurra
# Processing Record 19 of Set 4 | nelson bay
# Processing Record 20 of Set 4 | zhigansk
# Processing Record 21 of Set 4 | devils lake
# Processing Record 22 of Set 4 | masvingo
# Processing Record 23 of Set 4 | dunedin
# Processing Record 24 of Set 4 | bilibino
# Processing Record 25 of Set 4 | tagusao
# Processing Record 26 of Set 4 | cacapava do sul
# Processing Record 27 of Set 4 | hasaki
# Processing Record 28 of Set 4 | belmonte
# Processing Record 29 of Set 4 | east bethel
# Processing Record 30 of Set 4 | vila do maio
# Processing Record 31 of Set 4 | sechura
# Processing Record 32 of Set 4 | feijo
# Processing Record 33 of Set 4 | hermanus
# Processing Record 34 of Set 4 | moscow
# Processing Record 35 of Set 4 | san juan de colon
# Processing Record 36 of Set 4 | gidole
# Processing Record 37 of Set 4 | luderitz
# Processing Record 38 of Set 4 | ponta delgada
# Processing Record 39 of Set 4 | khatanga
# Processing Record 40 of Set 4 | hofn
# Processing Record 41 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 4 | kapaa
# Processing Record 44 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | zihuatanejo
# Processing Record 46 of Set 4 | qaqortoq
# Processing Record 47 of Set 4 | meulaboh
# Processing Record 48 of Set 4 | los llanos de aridane
# Processing Record 49 of Set 4 | sistranda
# Processing Record 50 of Set 4 | dujuma
# City not found. Skipping...
# Processing Record 1 of Set 5 | mehamn
# Processing Record 2 of Set 5 | ayan
# Processing Record 3 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 5 | pisco
# Processing Record 5 of Set 5 | rio grande
# Processing Record 6 of Set 5 | kjollefjord
# Processing Record 7 of Set 5 | sao joao da barra
# Processing Record 8 of Set 5 | morogoro
# Processing Record 9 of Set 5 | popondetta
# Processing Record 10 of Set 5 | ranot
# Processing Record 11 of Set 5 | vuktyl
# Processing Record 12 of Set 5 | maragogi
# Processing Record 13 of Set 5 | galle
# Processing Record 14 of Set 5 | vegueta
# Processing Record 15 of Set 5 | mount gambier
# Processing Record 16 of Set 5 | san joaquin
# Processing Record 17 of Set 5 | vardo
# Processing Record 18 of Set 5 | yaqui
# Processing Record 19 of Set 5 | geraldton
# Processing Record 20 of Set 5 | talnakh
# Processing Record 21 of Set 5 | hobart
# Processing Record 22 of Set 5 | yotsukaido
# Processing Record 23 of Set 5 | mitu
# Processing Record 24 of Set 5 | fairbanks
# Processing Record 25 of Set 5 | linqing
# Processing Record 26 of Set 5 | hoskote
# Processing Record 27 of Set 5 | nsanje
# Processing Record 28 of Set 5 | west bay
# Processing Record 29 of Set 5 | inta
# Processing Record 30 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 5 | morondava
# Processing Record 32 of Set 5 | orlik
# Processing Record 33 of Set 5 | grand gaube
# Processing Record 34 of Set 5 | souillac
# Processing Record 35 of Set 5 | catalina
# Processing Record 36 of Set 5 | carnarvon
# Processing Record 37 of Set 5 | leh
# Processing Record 38 of Set 5 | kubachi
# Processing Record 39 of Set 5 | saint-philippe
# Processing Record 40 of Set 5 | fortuna
# Processing Record 41 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 5 | teguise
# Processing Record 43 of Set 5 | vestmannaeyjar
# Processing Record 44 of Set 5 | okha
# Processing Record 45 of Set 5 | omboue
# Processing Record 46 of Set 5 | parabel
# Processing Record 47 of Set 5 | navabad
# City not found. Skipping...
# Processing Record 48 of Set 5 | aranos
# Processing Record 49 of Set 5 | cururupu
# Processing Record 50 of Set 5 | leningradskiy
# Processing Record 1 of Set 6 | mogadishu
# Processing Record 2 of Set 6 | staraya poltavka
# Processing Record 3 of Set 6 | le vauclin
# Processing Record 4 of Set 6 | uray
# Processing Record 5 of Set 6 | blieskastel
# Processing Record 6 of Set 6 | sola
# Processing Record 7 of Set 6 | bulalacao
# Processing Record 8 of Set 6 | nanortalik
# Processing Record 9 of Set 6 | kangaatsiaq
# Processing Record 10 of Set 6 | richards bay
# Processing Record 11 of Set 6 | corinth
# Processing Record 12 of Set 6 | bansang
# Processing Record 13 of Set 6 | silifke
# Processing Record 14 of Set 6 | hualmay
# Processing Record 15 of Set 6 | codrington
# Processing Record 16 of Set 6 | georgetown
# Processing Record 17 of Set 6 | hayden
# Processing Record 18 of Set 6 | alofi
# Processing Record 19 of Set 6 | esil
# Processing Record 20 of Set 6 | aklavik
# Processing Record 21 of Set 6 | finnsnes
# Processing Record 22 of Set 6 | palora
# Processing Record 23 of Set 6 | yulara
# Processing Record 24 of Set 6 | sabla
# Processing Record 25 of Set 6 | kruisfontein
# Processing Record 26 of Set 6 | dubai
# Processing Record 27 of Set 6 | clyde river
# Processing Record 28 of Set 6 | karpogory
# Processing Record 29 of Set 6 | nara
# Processing Record 30 of Set 6 | taoudenni
# Processing Record 31 of Set 6 | tuktoyaktuk
# Processing Record 32 of Set 6 | sitka
# Processing Record 33 of Set 6 | singkang
# Processing Record 34 of Set 6 | lata
# Processing Record 35 of Set 6 | half moon bay
# Processing Record 36 of Set 6 | te anau
# Processing Record 37 of Set 6 | troitsko-pechorsk
# Processing Record 38 of Set 6 | saint-georges
# Processing Record 39 of Set 6 | ahipara
# Processing Record 40 of Set 6 | kavieng
# Processing Record 41 of Set 6 | airai
# Processing Record 42 of Set 6 | finschhafen
# Processing Record 43 of Set 6 | kiunga
# Processing Record 44 of Set 6 | mahebourg
# Processing Record 45 of Set 6 | yar-sale
# Processing Record 46 of Set 6 | budaun
# Processing Record 47 of Set 6 | cidreira
# Processing Record 48 of Set 6 | kembolcha
# Processing Record 49 of Set 6 | ambilobe
# Processing Record 50 of Set 6 | pangnirtung
# Processing Record 1 of Set 7 | kirakira
# Processing Record 2 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 3 of Set 7 | beringovskiy
# Processing Record 4 of Set 7 | bennettsville
# Processing Record 5 of Set 7 | simao
# Processing Record 6 of Set 7 | lagoa
# Processing Record 7 of Set 7 | xinyu
# Processing Record 8 of Set 7 | bambous virieux
# Processing Record 9 of Set 7 | tkibuli
# Processing Record 10 of Set 7 | vyartsilya
# Processing Record 11 of Set 7 | chapais
# Processing Record 12 of Set 7 | capitao poco
# Processing Record 13 of Set 7 | jackson
# Processing Record 14 of Set 7 | upernavik
# Processing Record 15 of Set 7 | ballina
# Processing Record 16 of Set 7 | guozhen
# Processing Record 17 of Set 7 | benguela
# Processing Record 18 of Set 7 | valley station
# Processing Record 19 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 7 | dekoa
# City not found. Skipping...
# Processing Record 21 of Set 7 | linhares
# Processing Record 22 of Set 7 | alexandroupoli
# Processing Record 23 of Set 7 | wagar
# Processing Record 24 of Set 7 | takahashi
# Processing Record 25 of Set 7 | puerto escondido
# Processing Record 26 of Set 7 | tulum
# Processing Record 27 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 7 | hue
# Processing Record 29 of Set 7 | dehloran
# Processing Record 30 of Set 7 | puerto el triunfo
# Processing Record 31 of Set 7 | portland
# Processing Record 32 of Set 7 | berlevag
# Processing Record 33 of Set 7 | grand haven
# Processing Record 34 of Set 7 | camacha
# Processing Record 35 of Set 7 | esperance
# Processing Record 36 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 7 | bandarbeyla
# Processing Record 38 of Set 7 | hornepayne
# Processing Record 39 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 7 | garowe
# Processing Record 41 of Set 7 | rodotopion
# Processing Record 42 of Set 7 | turan
# Processing Record 43 of Set 7 | bandar-e lengeh
# Processing Record 44 of Set 7 | buraydah
# Processing Record 45 of Set 7 | shelburne
# Processing Record 46 of Set 7 | terra santa
# Processing Record 47 of Set 7 | yarmouth
# Processing Record 48 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 50 of Set 7 | nome
# Processing Record 1 of Set 8 | burica
# City not found. Skipping...
# Processing Record 2 of Set 8 | olovyannaya
# Processing Record 3 of Set 8 | ishinomaki
# Processing Record 4 of Set 8 | zaozerne
# Processing Record 5 of Set 8 | trincomalee
# Processing Record 6 of Set 8 | ambon
# Processing Record 7 of Set 8 | alugan
# Processing Record 8 of Set 8 | honningsvag
# Processing Record 9 of Set 8 | whitehorse
# Processing Record 10 of Set 8 | aljezur
# Processing Record 11 of Set 8 | veglie
# Processing Record 12 of Set 8 | komsomolskiy
# Processing Record 13 of Set 8 | balezino
# Processing Record 14 of Set 8 | astoria
# Processing Record 15 of Set 8 | wanning
# Processing Record 16 of Set 8 | fallon
# Processing Record 17 of Set 8 | severo-kurilsk
# Processing Record 18 of Set 8 | bathsheba
# Processing Record 19 of Set 8 | price
# Processing Record 20 of Set 8 | gannan
# Processing Record 21 of Set 8 | san remo
# Processing Record 22 of Set 8 | batsfjord
# Processing Record 23 of Set 8 | faanui
# Processing Record 24 of Set 8 | dingle
# Processing Record 25 of Set 8 | hithadhoo
# Processing Record 26 of Set 8 | bardiyah
# Processing Record 27 of Set 8 | beira
# Processing Record 28 of Set 8 | nishihara
# Processing Record 29 of Set 8 | havoysund
# Processing Record 30 of Set 8 | houma
# Processing Record 31 of Set 8 | havre
# Processing Record 32 of Set 8 | saldanha
# Processing Record 33 of Set 8 | shimoda
# Processing Record 34 of Set 8 | huarmey
# Processing Record 35 of Set 8 | port hardy
# Processing Record 36 of Set 8 | doka
# Processing Record 37 of Set 8 | santa rosa
# Processing Record 38 of Set 8 | lucknow
# Processing Record 39 of Set 8 | teya
# Processing Record 40 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 41 of Set 8 | kitim
# Processing Record 42 of Set 8 | bull savanna
# Processing Record 43 of Set 8 | sitamau
# Processing Record 44 of Set 8 | sioux lookout
# Processing Record 45 of Set 8 | menongue
# Processing Record 46 of Set 8 | rawson
# Processing Record 47 of Set 8 | klaksvik
# Processing Record 48 of Set 8 | margate
# Processing Record 49 of Set 8 | awjilah
# Processing Record 50 of Set 8 | atar
# Processing Record 1 of Set 9 | guanica
# Processing Record 2 of Set 9 | kupang
# Processing Record 3 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 9 | hamilton
# Processing Record 5 of Set 9 | quatre cocos
# Processing Record 6 of Set 9 | tarakan
# Processing Record 7 of Set 9 | thayetmyo
# Processing Record 8 of Set 9 | merauke
# Processing Record 9 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 9 | pombas
# Processing Record 11 of Set 9 | cockburn town
# Processing Record 12 of Set 9 | xai-xai
# Processing Record 13 of Set 9 | voznesenye
# Processing Record 14 of Set 9 | novyy urengoy
# Processing Record 15 of Set 9 | guerrero negro
# Processing Record 16 of Set 9 | fort payne
# Processing Record 17 of Set 9 | ulvik
# Processing Record 18 of Set 9 | chumikan
# Processing Record 19 of Set 9 | van
# Processing Record 20 of Set 9 | prachuap khiri khan
# Processing Record 21 of Set 9 | langsa
# Processing Record 22 of Set 9 | piterka
# Processing Record 23 of Set 9 | banda aceh
# Processing Record 24 of Set 9 | port shepstone
# Processing Record 25 of Set 9 | porto novo
# Processing Record 26 of Set 9 | axim
# Processing Record 27 of Set 9 | inongo
# Processing Record 28 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 9 | sawtell
# Processing Record 30 of Set 9 | baykit
# Processing Record 31 of Set 9 | ucluelet
# Processing Record 32 of Set 9 | katsuura
# Processing Record 33 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 9 | najran
# Processing Record 35 of Set 9 | chaumont
# Processing Record 36 of Set 9 | itaguai
# Processing Record 37 of Set 9 | lewiston
# Processing Record 38 of Set 9 | high level
# Processing Record 39 of Set 9 | vao
# Processing Record 40 of Set 9 | jensen beach
# Processing Record 41 of Set 9 | podgornoye
# Processing Record 42 of Set 9 | plettenberg bay
# Processing Record 43 of Set 9 | ardakan
# Processing Record 44 of Set 9 | zhezkazgan
# Processing Record 45 of Set 9 | puerto madryn
# Processing Record 46 of Set 9 | christchurch
# Processing Record 47 of Set 9 | erenhot
# Processing Record 48 of Set 9 | manta
# Processing Record 49 of Set 9 | nalut
# Processing Record 50 of Set 9 | birjand
# Processing Record 1 of Set 10 | panama city
# Processing Record 2 of Set 10 | orotukan
# Processing Record 3 of Set 10 | black river
# Processing Record 4 of Set 10 | eenhana
# Processing Record 5 of Set 10 | sao miguel do araguaia
# Processing Record 6 of Set 10 | san policarpo
# Processing Record 7 of Set 10 | nicoya
# Processing Record 8 of Set 10 | teknaf
# Processing Record 9 of Set 10 | mangalia
# Processing Record 10 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 10 | yurimaguas
# Processing Record 12 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 13 of Set 10 | nijar
# Processing Record 14 of Set 10 | sinnamary
# Processing Record 15 of Set 10 | riyadh
# Processing Record 16 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 17 of Set 10 | moa
# Processing Record 18 of Set 10 | russell
# Processing Record 19 of Set 10 | ekpoma
# Processing Record 20 of Set 10 | mackenzie
# Processing Record 21 of Set 10 | niquelandia
# Processing Record 22 of Set 10 | tazovskiy
# Processing Record 23 of Set 10 | laguna
# Processing Record 24 of Set 10 | kaeo
# Processing Record 25 of Set 10 | kabalo
# Processing Record 26 of Set 10 | dukat
# Processing Record 27 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 28 of Set 10 | namibe
# Processing Record 29 of Set 10 | luanda
# Processing Record 30 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 10 | pringsewu
# Processing Record 32 of Set 10 | zeya
# Processing Record 33 of Set 10 | kastamonu
# Processing Record 34 of Set 10 | palmas
# Processing Record 35 of Set 10 | sant julia de loria
# Processing Record 36 of Set 10 | okhotsk
# Processing Record 37 of Set 10 | tolaga bay
# Processing Record 38 of Set 10 | cairns
# Processing Record 39 of Set 10 | eureka
# Processing Record 40 of Set 10 | wick
# Processing Record 41 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 10 | muroto
# Processing Record 43 of Set 10 | ilulissat
# Processing Record 44 of Set 10 | tautira
# Processing Record 45 of Set 10 | scottsbluff
# Processing Record 46 of Set 10 | kismayo
# Processing Record 47 of Set 10 | barcelos
# Processing Record 48 of Set 10 | baglung
# Processing Record 49 of Set 10 | narsaq
# Processing Record 50 of Set 10 | deniliquin
# Processing Record 1 of Set 11 | naryan-mar
# Processing Record 2 of Set 11 | kaura namoda
# Processing Record 3 of Set 11 | manokwari
# Processing Record 4 of Set 11 | torbay
# Processing Record 5 of Set 11 | karratha
# Processing Record 6 of Set 11 | thibodaux
# Processing Record 7 of Set 11 | mari-turek
# Processing Record 8 of Set 11 | yaan
# Processing Record 9 of Set 11 | evensk
# Processing Record 10 of Set 11 | angol
# Processing Record 11 of Set 11 | mugumu
# Processing Record 12 of Set 11 | redwater
# Processing Record 13 of Set 11 | kamnik
# Processing Record 14 of Set 11 | shuangyang
# Processing Record 15 of Set 11 | aripuana
# Processing Record 16 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 11 | ordynskoye
# Processing Record 18 of Set 11 | phan thiet
# Processing Record 19 of Set 11 | porto belo
# Processing Record 20 of Set 11 | lake havasu city
# Processing Record 21 of Set 11 | hami
# Processing Record 22 of Set 11 | burnie
# Processing Record 23 of Set 11 | abu samrah
# Processing Record 24 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 11 | atherton
# Processing Record 26 of Set 11 | ossora
# Processing Record 27 of Set 11 | morehead
# Processing Record 28 of Set 11 | roebourne
# Processing Record 29 of Set 11 | kabompo
# Processing Record 30 of Set 11 | eyl
# Processing Record 31 of Set 11 | broken hill
# Processing Record 32 of Set 11 | bushehr
# Processing Record 33 of Set 11 | onega
# Processing Record 34 of Set 11 | viedma
# Processing Record 35 of Set 11 | mwene-ditu
# Processing Record 36 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 11 | westport
# Processing Record 38 of Set 11 | izumo
# Processing Record 39 of Set 11 | la tuque
# Processing Record 40 of Set 11 | gamba
# Processing Record 41 of Set 11 | sarankhola
# Processing Record 42 of Set 11 | ituporanga
# Processing Record 43 of Set 11 | vila
# Processing Record 44 of Set 11 | niort
# Processing Record 45 of Set 11 | cubulco
# Processing Record 46 of Set 11 | kalmunai
# Processing Record 47 of Set 11 | dakoro
# Processing Record 48 of Set 11 | jennings
# Processing Record 49 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 11 | arcata
# Processing Record 1 of Set 12 | labuhan
# Processing Record 2 of Set 12 | maniitsoq
# Processing Record 3 of Set 12 | srandakan
# Processing Record 4 of Set 12 | san carlos de bariloche
# Processing Record 5 of Set 12 | bagn
# Processing Record 6 of Set 12 | hoa binh
# Processing Record 7 of Set 12 | avera
# Processing Record 8 of Set 12 | xicotencatl
# Processing Record 9 of Set 12 | verkhoyansk
# Processing Record 10 of Set 12 | locri
# Processing Record 11 of Set 12 | svetlogorsk
# Processing Record 12 of Set 12 | conway
# Processing Record 13 of Set 12 | santana do livramento
# Processing Record 14 of Set 12 | shache
# Processing Record 15 of Set 12 | liuli
# Processing Record 16 of Set 12 | marzuq
# Processing Record 17 of Set 12 | halifax
# Processing Record 18 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 12 | gbarnga
# Processing Record 20 of Set 12 | faya
# Processing Record 21 of Set 12 | thyboron
# Processing Record 22 of Set 12 | albury
# Processing Record 23 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 12 | lalmohan
# Processing Record 25 of Set 12 | svetlaya
# Processing Record 26 of Set 12 | astara
# Processing Record 27 of Set 12 | benxi
# Processing Record 28 of Set 12 | wajima
# Processing Record 29 of Set 12 | homer
# Processing Record 30 of Set 12 | parrita
# Processing Record 31 of Set 12 | sao geraldo do araguaia
# Processing Record 32 of Set 12 | colares
# Processing Record 33 of Set 12 | vostok
# Processing Record 34 of Set 12 | borogontsy
# Processing Record 35 of Set 12 | narnaul
# Processing Record 36 of Set 12 | ocos
# Processing Record 37 of Set 12 | maruko
# Processing Record 38 of Set 12 | sungaipenuh
# Processing Record 39 of Set 12 | areosa
# Processing Record 40 of Set 12 | pitkyaranta
# Processing Record 41 of Set 12 | marsh harbour
# Processing Record 42 of Set 12 | tshela
# Processing Record 43 of Set 12 | mucurapo
# Processing Record 44 of Set 12 | alakurtti
# Processing Record 45 of Set 12 | asau
# Processing Record 46 of Set 12 | akonolinga
# Processing Record 47 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 48 of Set 12 | gorele
# Processing Record 49 of Set 12 | itarema
# Processing Record 50 of Set 12 | kavali
# Processing Record 1 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 2 of Set 13 | garmsar
# Processing Record 3 of Set 13 | eruwa
# Processing Record 4 of Set 13 | cloquet
# Processing Record 5 of Set 13 | anadyr
# Processing Record 6 of Set 13 | kilkenny
# Processing Record 7 of Set 13 | caravelas
# Processing Record 8 of Set 13 | dali
# Processing Record 9 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 13 | arman
# Processing Record 11 of Set 13 | fuyang
# Processing Record 12 of Set 13 | yabrud
# Processing Record 13 of Set 13 | ca mau
# Processing Record 14 of Set 13 | antalaha
# Processing Record 15 of Set 13 | gatesville
# Processing Record 16 of Set 13 | pionerskiy
# Processing Record 17 of Set 13 | el tigre
# Processing Record 18 of Set 13 | waverley
# Processing Record 19 of Set 13 | eidsvoll
# Processing Record 20 of Set 13 | grindavik
# Processing Record 21 of Set 13 | parkes
# Processing Record 22 of Set 13 | vaitape
# Processing Record 23 of Set 13 | byron bay
# Processing Record 24 of Set 13 | shibarghan
# City not found. Skipping...
# Processing Record 25 of Set 13 | alexandria
# Processing Record 26 of Set 13 | sao jose da coroa grande
# Processing Record 27 of Set 13 | bermeo
# Processing Record 28 of Set 13 | homestead
# Processing Record 29 of Set 13 | carauari
# Processing Record 30 of Set 13 | ancud
# Processing Record 31 of Set 13 | mahajanga
# Processing Record 32 of Set 13 | inhambane
# Processing Record 33 of Set 13 | flin flon
# Processing Record 34 of Set 13 | iranshahr
# Processing Record 35 of Set 13 | tay ninh
# Processing Record 36 of Set 13 | shingu
# Processing Record 37 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 13 | khvatovka
# Processing Record 39 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 40 of Set 13 | goulburn
# Processing Record 41 of Set 13 | semey
# Processing Record 42 of Set 13 | denpasar
# Processing Record 43 of Set 13 | presidencia roque saenz pena
# Processing Record 44 of Set 13 | coutances
# Processing Record 45 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 46 of Set 13 | buchanan
# Processing Record 47 of Set 13 | ust-tsilma
# Processing Record 48 of Set 13 | padang
# Processing Record 49 of Set 13 | samarai
# Processing Record 50 of Set 13 | saint-augustin
# Processing Record 1 of Set 14 | kalavad
# Processing Record 2 of Set 14 | oltu
# Processing Record 3 of Set 14 | palmer
# Processing Record 4 of Set 14 | hambantota
# Processing Record 5 of Set 14 | auki
# Processing Record 6 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 14 | acapulco
# Processing Record 8 of Set 14 | vanavara
# Processing Record 9 of Set 14 | campeche
# Processing Record 10 of Set 14 | denizli
# Processing Record 11 of Set 14 | salalah
# Processing Record 12 of Set 14 | tiznit
# Processing Record 13 of Set 14 | belle fourche
# Processing Record 14 of Set 14 | pahalgam
# Processing Record 15 of Set 14 | porangatu
# Processing Record 16 of Set 14 | ekibastuz
# Processing Record 17 of Set 14 | yacuiba
# Processing Record 18 of Set 14 | vesoul
# Processing Record 19 of Set 14 | lufilufi
# Processing Record 20 of Set 14 | mzimba
# Processing Record 21 of Set 14 | prince rupert
# Processing Record 22 of Set 14 | charlottesville
# Processing Record 23 of Set 14 | korla
# Processing Record 24 of Set 14 | lokeren
# Processing Record 25 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 14 | saint-pierre
# Processing Record 27 of Set 14 | stabat
# Processing Record 28 of Set 14 | grand-lahou
# Processing Record 29 of Set 14 | chontalpa
# Processing Record 30 of Set 14 | necochea
# Processing Record 31 of Set 14 | bonavista
# Processing Record 32 of Set 14 | pangkalanbuun
# Processing Record 33 of Set 14 | eugene
# Processing Record 34 of Set 14 | la ronge
# Processing Record 35 of Set 14 | sao sebastiao do paraiso
# Processing Record 36 of Set 14 | dalvik
# Processing Record 37 of Set 14 | rosario do sul
# Processing Record 38 of Set 14 | corinto
# Processing Record 39 of Set 14 | canutama
# Processing Record 40 of Set 14 | mittagong
# Processing Record 41 of Set 14 | bayir
# Processing Record 42 of Set 14 | guinguineo
# Processing Record 43 of Set 14 | kribi
# Processing Record 44 of Set 14 | oranjemund
# Processing Record 45 of Set 14 | flinders
# Processing Record 46 of Set 14 | chanika
# Processing Record 47 of Set 14 | khandbari
# Processing Record 48 of Set 14 | lisakovsk
# Processing Record 49 of Set 14 | visby
# Processing Record 50 of Set 14 | moerai
# Processing Record 1 of Set 15 | rockport
# Processing Record 2 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 3 of Set 15 | hamza
# Processing Record 4 of Set 15 | merrill
# Processing Record 5 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 6 of Set 15 | santa maria
# Processing Record 7 of Set 15 | uarini
# Processing Record 8 of Set 15 | guilin
# Processing Record 9 of Set 15 | khandyga
# Processing Record 10 of Set 15 | ust-karsk
# Processing Record 11 of Set 15 | piopio
# Processing Record 12 of Set 15 | yangambi
# Processing Record 13 of Set 15 | george town
# Processing Record 14 of Set 15 | zhangye
# Processing Record 15 of Set 15 | sal rei
# Processing Record 16 of Set 15 | totness
# Processing Record 17 of Set 15 | conde
# Processing Record 18 of Set 15 | sisimiut
# Processing Record 19 of Set 15 | lubango
# Processing Record 20 of Set 15 | harper
# Processing Record 21 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 22 of Set 15 | anisoc
# Processing Record 23 of Set 15 | carlyle
# Processing Record 24 of Set 15 | nagorsk
# Processing Record 25 of Set 15 | ekhabi
# Processing Record 26 of Set 15 | solnechnyy
# Processing Record 27 of Set 15 | taichung
# Processing Record 28 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 15 | trinidad
# Processing Record 30 of Set 15 | rodrigues alves
# Processing Record 31 of Set 15 | krasnyy chikoy
# Processing Record 32 of Set 15 | birecik
# Processing Record 33 of Set 15 | marostica
# Processing Record 34 of Set 15 | cayenne
# Processing Record 35 of Set 15 | akyab
# Processing Record 36 of Set 15 | hay river
# Processing Record 37 of Set 15 | encantado
# Processing Record 38 of Set 15 | praia
# Processing Record 39 of Set 15 | araguari
# Processing Record 40 of Set 15 | marathon
# Processing Record 41 of Set 15 | tucurui
# Processing Record 42 of Set 15 | moussoro
# Processing Record 43 of Set 15 | pelym
# Processing Record 44 of Set 15 | port pirie
# Processing Record 45 of Set 15 | nyahururu
# Processing Record 46 of Set 15 | maine-soroa
# Processing Record 47 of Set 15 | abu zabad
# Processing Record 48 of Set 15 | sorong
# Processing Record 49 of Set 15 | kernersville
# Processing Record 50 of Set 15 | isangel
# Processing Record 1 of Set 16 | nola
# Processing Record 2 of Set 16 | nemuro
# Processing Record 3 of Set 16 | ridgecrest
# Processing Record 4 of Set 16 | concordia
# Processing Record 5 of Set 16 | bokspits
# City not found. Skipping...
# Processing Record 6 of Set 16 | ayr
# Processing Record 7 of Set 16 | zyryanka
# Processing Record 8 of Set 16 | saint johnsbury
# Processing Record 9 of Set 16 | ostrovnoy
# Processing Record 10 of Set 16 | yeniseysk
# Processing Record 11 of Set 16 | milkovo
# Processing Record 12 of Set 16 | bintulu
# Processing Record 13 of Set 16 | nago
# Processing Record 14 of Set 16 | ornskoldsvik
# Processing Record 15 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 16 | riberalta
# Processing Record 17 of Set 16 | gedo
# Processing Record 18 of Set 16 | pecos
# Processing Record 19 of Set 16 | bodden town
# Processing Record 20 of Set 16 | vanimo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Sao Filipe      CV  14.8961  -24.4956     73.42        77           4
# 1        Kantilo      IN  20.3500   85.1833     67.86        88           4
# 2  San Cristobal      VE   7.7669  -72.2250     68.31        56          19
# 3        Rikitea      PF -23.1203 -134.9692     78.69        73         100
# 4        Paamiut      GL  61.9940  -49.6678     12.67        60         100
# 5      Eganville      CA  45.5334  -77.0994     32.52        99         100
# 6   Rio Gallegos      AR -51.6226  -69.2181     57.25        58          75
# 7        Ushuaia      AR -54.8000  -68.3000     44.26        61          75
# 8           Lebu      CL -37.6167  -73.6500     60.78        87          54
# 9       Sobolevo      RU  54.4299   31.8996     24.08        97         100
#
#    Wind Speed Current Description
# 0       12.75           clear sky
# 1        1.66           clear sky
# 2        1.97          few clouds
# 3        8.05     overcast clouds
# 4       20.22     overcast clouds
# 5        4.38                snow
# 6       17.27       broken clouds
# 7       24.16       broken clouds
# 8       10.85       broken clouds
# 9        6.62                snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
