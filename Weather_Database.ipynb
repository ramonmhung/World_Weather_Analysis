# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/ramonmanrique/opt/anaconda3/lib/python3.9/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/ramonmanrique/opt/anaconda3/lib/python3.9/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | geraldton
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | san angelo
# Processing Record 7 of Set 1 | faanui
# Processing Record 8 of Set 1 | lavrentiya
# Processing Record 9 of Set 1 | grootfontein
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | cayenne
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | carnarvon
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | carupano
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | terrace
# Processing Record 19 of Set 1 | shubarshi
# Processing Record 20 of Set 1 | clyde river
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | amapa
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | phan thiet
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | goderich
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | beringovskiy
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | narsaq
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | margate
# Processing Record 41 of Set 1 | constitucion
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | tuatapere
# Processing Record 45 of Set 1 | hopkinsville
# Processing Record 46 of Set 1 | yarmouth
# Processing Record 47 of Set 1 | champerico
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | oloron-sainte-marie
# Processing Record 50 of Set 1 | tiksi
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | san vicente
# Processing Record 3 of Set 2 | mehamn
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 2 | wanning
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | guerrero negro
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | iqaluit
# Processing Record 13 of Set 2 | byron bay
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | san andres
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | mar del plata
# Processing Record 18 of Set 2 | nome
# Processing Record 19 of Set 2 | broken hill
# Processing Record 20 of Set 2 | halifax
# Processing Record 21 of Set 2 | port elizabeth
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | juybar
# Processing Record 24 of Set 2 | lohja
# Processing Record 25 of Set 2 | xuchang
# Processing Record 26 of Set 2 | viedma
# Processing Record 27 of Set 2 | skrunda
# Processing Record 28 of Set 2 | helena
# Processing Record 29 of Set 2 | hay river
# Processing Record 30 of Set 2 | maceio
# Processing Record 31 of Set 2 | presidencia roque saenz pena
# Processing Record 32 of Set 2 | oudtshoorn
# Processing Record 33 of Set 2 | barnstaple
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | provideniya
# Processing Record 36 of Set 2 | vila velha
# Processing Record 37 of Set 2 | baruun-urt
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | volda
# Processing Record 40 of Set 2 | mandalgovi
# Processing Record 41 of Set 2 | chokurdakh
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | urengoy
# Processing Record 44 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | erdaojiang
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | ao luk
# City not found. Skipping...
# Processing Record 49 of Set 2 | saskylakh
# Processing Record 50 of Set 2 | teya
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | esna
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | ancud
# Processing Record 5 of Set 3 | khandagayty
# Processing Record 6 of Set 3 | springbok
# Processing Record 7 of Set 3 | pushkinskiye gory
# Processing Record 8 of Set 3 | eureka
# Processing Record 9 of Set 3 | juneau
# Processing Record 10 of Set 3 | sitka
# Processing Record 11 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 3 | severo-kurilsk
# Processing Record 13 of Set 3 | pevek
# Processing Record 14 of Set 3 | pecos
# Processing Record 15 of Set 3 | roma
# Processing Record 16 of Set 3 | christchurch
# Processing Record 17 of Set 3 | haines junction
# Processing Record 18 of Set 3 | talnakh
# Processing Record 19 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 3 | vila franca do campo
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | shar
# Processing Record 23 of Set 3 | kirakira
# Processing Record 24 of Set 3 | chapais
# Processing Record 25 of Set 3 | ambilobe
# Processing Record 26 of Set 3 | halvad
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | kruisfontein
# Processing Record 29 of Set 3 | hamina
# Processing Record 30 of Set 3 | mangrol
# Processing Record 31 of Set 3 | mitsamiouli
# Processing Record 32 of Set 3 | madinat sittah uktubar
# Processing Record 33 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 34 of Set 3 | yulara
# Processing Record 35 of Set 3 | jiwani
# Processing Record 36 of Set 3 | atsiki
# City not found. Skipping...
# Processing Record 37 of Set 3 | qingdao
# Processing Record 38 of Set 3 | brandon
# Processing Record 39 of Set 3 | bethel
# Processing Record 40 of Set 3 | warmbad
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | ust-kuyga
# Processing Record 44 of Set 3 | ferrol
# Processing Record 45 of Set 3 | outram
# Processing Record 46 of Set 3 | sola
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | carutapera
# Processing Record 50 of Set 3 | te anau
# Processing Record 1 of Set 4 | grand gaube
# Processing Record 2 of Set 4 | port blair
# Processing Record 3 of Set 4 | saint-pierre
# Processing Record 4 of Set 4 | sirsaganj
# Processing Record 5 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 4 | korla
# Processing Record 7 of Set 4 | moyale
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | bridgton
# Processing Record 10 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 4 | westpunt
# City not found. Skipping...
# Processing Record 13 of Set 4 | bredasdorp
# Processing Record 14 of Set 4 | esperance
# Processing Record 15 of Set 4 | chute-aux-outardes
# Processing Record 16 of Set 4 | vao
# Processing Record 17 of Set 4 | avon
# Processing Record 18 of Set 4 | pekalongan
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | luderitz
# Processing Record 21 of Set 4 | castelldefels
# Processing Record 22 of Set 4 | gaoual
# Processing Record 23 of Set 4 | olden
# Processing Record 24 of Set 4 | lazaro cardenas
# Processing Record 25 of Set 4 | scottsboro
# Processing Record 26 of Set 4 | yichang
# Processing Record 27 of Set 4 | katsuura
# Processing Record 28 of Set 4 | labuhan
# Processing Record 29 of Set 4 | zharkent
# Processing Record 30 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 4 | soma
# Processing Record 32 of Set 4 | port lincoln
# Processing Record 33 of Set 4 | cabo san lucas
# Processing Record 34 of Set 4 | husavik
# Processing Record 35 of Set 4 | okhotsk
# Processing Record 36 of Set 4 | puri
# Processing Record 37 of Set 4 | leningradskiy
# Processing Record 38 of Set 4 | bone
# Processing Record 39 of Set 4 | broome
# Processing Record 40 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 4 | lagoa
# Processing Record 42 of Set 4 | victoria
# Processing Record 43 of Set 4 | khatanga
# Processing Record 44 of Set 4 | karratha
# Processing Record 45 of Set 4 | shediac
# Processing Record 46 of Set 4 | boyolangu
# Processing Record 47 of Set 4 | chernyshevskiy
# Processing Record 48 of Set 4 | shenjiamen
# Processing Record 49 of Set 4 | antalaha
# Processing Record 50 of Set 4 | hendijan
# City not found. Skipping...
# Processing Record 1 of Set 5 | lompoc
# Processing Record 2 of Set 5 | swift current
# Processing Record 3 of Set 5 | nanortalik
# Processing Record 4 of Set 5 | padang
# Processing Record 5 of Set 5 | flinders
# Processing Record 6 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 5 | henties bay
# Processing Record 8 of Set 5 | vanavara
# Processing Record 9 of Set 5 | vung tau
# Processing Record 10 of Set 5 | general roca
# Processing Record 11 of Set 5 | denpasar
# Processing Record 12 of Set 5 | lalibela
# Processing Record 13 of Set 5 | noumea
# Processing Record 14 of Set 5 | norman wells
# Processing Record 15 of Set 5 | mareeba
# Processing Record 16 of Set 5 | werda
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | san quintin
# Processing Record 19 of Set 5 | cockburn town
# Processing Record 20 of Set 5 | ishigaki
# Processing Record 21 of Set 5 | dawei
# Processing Record 22 of Set 5 | nogent-le-rotrou
# Processing Record 23 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 5 | srandakan
# Processing Record 25 of Set 5 | sfantu gheorghe
# Processing Record 26 of Set 5 | ozinki
# Processing Record 27 of Set 5 | hofn
# Processing Record 28 of Set 5 | souillac
# Processing Record 29 of Set 5 | vardo
# Processing Record 30 of Set 5 | nuuk
# Processing Record 31 of Set 5 | yuty
# Processing Record 32 of Set 5 | shimoda
# Processing Record 33 of Set 5 | cape town
# Processing Record 34 of Set 5 | chihuahua
# Processing Record 35 of Set 5 | alofi
# Processing Record 36 of Set 5 | plettenberg bay
# Processing Record 37 of Set 5 | iwanai
# Processing Record 38 of Set 5 | zyryanka
# Processing Record 39 of Set 5 | airai
# Processing Record 40 of Set 5 | atar
# Processing Record 41 of Set 5 | fallon
# Processing Record 42 of Set 5 | olga
# Processing Record 43 of Set 5 | aswan
# Processing Record 44 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 5 | charters towers
# Processing Record 46 of Set 5 | biak
# Processing Record 47 of Set 5 | matay
# Processing Record 48 of Set 5 | bilma
# Processing Record 49 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 5 | filingue
# Processing Record 1 of Set 6 | mutare
# Processing Record 2 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 6 | honiara
# Processing Record 4 of Set 6 | sysert
# Processing Record 5 of Set 6 | solnechnyy
# Processing Record 6 of Set 6 | yumen
# Processing Record 7 of Set 6 | itambe
# Processing Record 8 of Set 6 | cidreira
# Processing Record 9 of Set 6 | makakilo city
# Processing Record 10 of Set 6 | comonfort
# Processing Record 11 of Set 6 | fortuna
# Processing Record 12 of Set 6 | ambanja
# Processing Record 13 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 14 of Set 6 | rantauprapat
# Processing Record 15 of Set 6 | charyshskoye
# Processing Record 16 of Set 6 | dong hoi
# Processing Record 17 of Set 6 | bengkulu
# Processing Record 18 of Set 6 | iquitos
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | mumford
# Processing Record 21 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 6 | langsa
# Processing Record 23 of Set 6 | chuy
# Processing Record 24 of Set 6 | naze
# Processing Record 25 of Set 6 | kathmandu
# Processing Record 26 of Set 6 | sobolevo
# Processing Record 27 of Set 6 | kahului
# Processing Record 28 of Set 6 | jining
# Processing Record 29 of Set 6 | karlstad
# Processing Record 30 of Set 6 | caldwell
# Processing Record 31 of Set 6 | linkoping
# Processing Record 32 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 6 | manokwari
# Processing Record 34 of Set 6 | makhachkala
# Processing Record 35 of Set 6 | palmer
# Processing Record 36 of Set 6 | yanam
# Processing Record 37 of Set 6 | nikolskoye
# Processing Record 38 of Set 6 | sisimiut
# Processing Record 39 of Set 6 | codrington
# Processing Record 40 of Set 6 | koumac
# Processing Record 41 of Set 6 | raudeberg
# Processing Record 42 of Set 6 | yenagoa
# Processing Record 43 of Set 6 | ahipara
# Processing Record 44 of Set 6 | nishihara
# Processing Record 45 of Set 6 | bathsheba
# Processing Record 46 of Set 6 | hasaki
# Processing Record 47 of Set 6 | saskatoon
# Processing Record 48 of Set 6 | barbalha
# Processing Record 49 of Set 6 | manzhouli
# Processing Record 50 of Set 6 | dutlwe
# Processing Record 1 of Set 7 | loveland
# Processing Record 2 of Set 7 | faya
# Processing Record 3 of Set 7 | marsa matruh
# Processing Record 4 of Set 7 | djibo
# Processing Record 5 of Set 7 | bozoum
# Processing Record 6 of Set 7 | krasnoselkup
# Processing Record 7 of Set 7 | esmeraldas
# Processing Record 8 of Set 7 | buta
# Processing Record 9 of Set 7 | kardailovo
# Processing Record 10 of Set 7 | jiaozuo
# Processing Record 11 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 7 | sao jose da coroa grande
# Processing Record 13 of Set 7 | ashcroft
# Processing Record 14 of Set 7 | mahenge
# Processing Record 15 of Set 7 | andenes
# Processing Record 16 of Set 7 | olafsvik
# Processing Record 17 of Set 7 | inhambane
# Processing Record 18 of Set 7 | matehuala
# Processing Record 19 of Set 7 | aykino
# Processing Record 20 of Set 7 | westport
# Processing Record 21 of Set 7 | vestmannaeyjar
# Processing Record 22 of Set 7 | paamiut
# Processing Record 23 of Set 7 | rock springs
# Processing Record 24 of Set 7 | tahe
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | dingle
# Processing Record 27 of Set 7 | amethi
# Processing Record 28 of Set 7 | wasilla
# Processing Record 29 of Set 7 | bahir dar
# Processing Record 30 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 31 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 7 | antigonish
# Processing Record 33 of Set 7 | los llanos de aridane
# Processing Record 34 of Set 7 | pombas
# Processing Record 35 of Set 7 | bolkhov
# Processing Record 36 of Set 7 | lima
# Processing Record 37 of Set 7 | agadez
# Processing Record 38 of Set 7 | east london
# Processing Record 39 of Set 7 | tamiahua
# Processing Record 40 of Set 7 | ambulu
# Processing Record 41 of Set 7 | thinadhoo
# Processing Record 42 of Set 7 | alta floresta
# Processing Record 43 of Set 7 | namibe
# Processing Record 44 of Set 7 | shitanjing
# Processing Record 45 of Set 7 | nampula
# Processing Record 46 of Set 7 | roanoke
# Processing Record 47 of Set 7 | tura
# Processing Record 48 of Set 7 | meulaboh
# Processing Record 49 of Set 7 | darhan
# Processing Record 50 of Set 7 | saldanha
# Processing Record 1 of Set 8 | capaccio
# Processing Record 2 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 3 of Set 8 | laguna
# Processing Record 4 of Set 8 | srednekolymsk
# Processing Record 5 of Set 8 | kitakata
# Processing Record 6 of Set 8 | sambava
# Processing Record 7 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 8 of Set 8 | kokopo
# Processing Record 9 of Set 8 | kisangani
# Processing Record 10 of Set 8 | sangar
# Processing Record 11 of Set 8 | jiazi
# Processing Record 12 of Set 8 | pochutla
# Processing Record 13 of Set 8 | seoul
# Processing Record 14 of Set 8 | hamilton
# Processing Record 15 of Set 8 | arman
# Processing Record 16 of Set 8 | jipijapa
# Processing Record 17 of Set 8 | isangel
# Processing Record 18 of Set 8 | dubbo
# Processing Record 19 of Set 8 | klaksvik
# Processing Record 20 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 21 of Set 8 | necochea
# Processing Record 22 of Set 8 | boguchany
# Processing Record 23 of Set 8 | nicoya
# Processing Record 24 of Set 8 | parry sound
# Processing Record 25 of Set 8 | den helder
# Processing Record 26 of Set 8 | okha
# Processing Record 27 of Set 8 | deputatskiy
# Processing Record 28 of Set 8 | lockport
# Processing Record 29 of Set 8 | dawlatabad
# Processing Record 30 of Set 8 | grindavik
# Processing Record 31 of Set 8 | vilyuysk
# Processing Record 32 of Set 8 | buala
# Processing Record 33 of Set 8 | vytegra
# Processing Record 34 of Set 8 | upington
# Processing Record 35 of Set 8 | cap malheureux
# Processing Record 36 of Set 8 | yeppoon
# Processing Record 37 of Set 8 | santona
# Processing Record 38 of Set 8 | santa maria
# Processing Record 39 of Set 8 | dangriga
# Processing Record 40 of Set 8 | kaduqli
# Processing Record 41 of Set 8 | manzil kamil
# Processing Record 42 of Set 8 | fonte boa
# Processing Record 43 of Set 8 | chik
# Processing Record 44 of Set 8 | tarakan
# Processing Record 45 of Set 8 | aklavik
# Processing Record 46 of Set 8 | marsh harbour
# Processing Record 47 of Set 8 | ahuimanu
# Processing Record 48 of Set 8 | gazanjyk
# Processing Record 49 of Set 8 | ngunguru
# Processing Record 50 of Set 8 | northam
# Processing Record 1 of Set 9 | matasari
# Processing Record 2 of Set 9 | mount gambier
# Processing Record 3 of Set 9 | raton
# Processing Record 4 of Set 9 | zhanakorgan
# Processing Record 5 of Set 9 | mantua
# Processing Record 6 of Set 9 | muravlenko
# Processing Record 7 of Set 9 | coruripe
# Processing Record 8 of Set 9 | laredo
# Processing Record 9 of Set 9 | visnes
# Processing Record 10 of Set 9 | shimla
# Processing Record 11 of Set 9 | gushikawa
# Processing Record 12 of Set 9 | kawalu
# Processing Record 13 of Set 9 | brigantine
# Processing Record 14 of Set 9 | nhulunbuy
# Processing Record 15 of Set 9 | rochelle
# Processing Record 16 of Set 9 | saint-georges
# Processing Record 17 of Set 9 | chicama
# Processing Record 18 of Set 9 | gravdal
# Processing Record 19 of Set 9 | mendota
# Processing Record 20 of Set 9 | qasigiannguit
# Processing Record 21 of Set 9 | sao joao da barra
# Processing Record 22 of Set 9 | caravelas
# Processing Record 23 of Set 9 | rodrigues alves
# Processing Record 24 of Set 9 | belyy yar
# Processing Record 25 of Set 9 | pundaguitan
# Processing Record 26 of Set 9 | high rock
# Processing Record 27 of Set 9 | lida
# Processing Record 28 of Set 9 | hibbing
# Processing Record 29 of Set 9 | saurimo
# Processing Record 30 of Set 9 | zhigansk
# Processing Record 31 of Set 9 | gryazovets
# Processing Record 32 of Set 9 | manaure
# Processing Record 33 of Set 9 | ostrovnoy
# Processing Record 34 of Set 9 | huarmey
# Processing Record 35 of Set 9 | kalemie
# Processing Record 36 of Set 9 | atessa
# Processing Record 37 of Set 9 | vigrestad
# Processing Record 38 of Set 9 | ampanihy
# Processing Record 39 of Set 9 | nara
# Processing Record 40 of Set 9 | tsabong
# Processing Record 41 of Set 9 | fort smith
# Processing Record 42 of Set 9 | sioux lookout
# Processing Record 43 of Set 9 | panguna
# Processing Record 44 of Set 9 | auki
# Processing Record 45 of Set 9 | ratnagiri
# Processing Record 46 of Set 9 | guekedou
# City not found. Skipping...
# Processing Record 47 of Set 9 | yushu
# Processing Record 48 of Set 9 | ipora
# Processing Record 49 of Set 9 | tymovskoye
# Processing Record 50 of Set 9 | bilibino
# Processing Record 1 of Set 10 | saint george
# Processing Record 2 of Set 10 | sibu
# Processing Record 3 of Set 10 | tautira
# Processing Record 4 of Set 10 | phalodi
# Processing Record 5 of Set 10 | veinticinco de mayo
# Processing Record 6 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 10 | buinsk
# Processing Record 8 of Set 10 | menongue
# Processing Record 9 of Set 10 | salisbury
# Processing Record 10 of Set 10 | port said
# Processing Record 11 of Set 10 | coihaique
# Processing Record 12 of Set 10 | yining
# Processing Record 13 of Set 10 | xining
# Processing Record 14 of Set 10 | alice springs
# Processing Record 15 of Set 10 | san cristobal
# Processing Record 16 of Set 10 | kazachinskoye
# Processing Record 17 of Set 10 | walvis bay
# Processing Record 18 of Set 10 | siguiri
# Processing Record 19 of Set 10 | aleksandrov gay
# Processing Record 20 of Set 10 | pyaozerskiy
# Processing Record 21 of Set 10 | dali
# Processing Record 22 of Set 10 | morondava
# Processing Record 23 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 24 of Set 10 | kita
# Processing Record 25 of Set 10 | dhanwar
# Processing Record 26 of Set 10 | leh
# Processing Record 27 of Set 10 | marovoay
# Processing Record 28 of Set 10 | suluq
# Processing Record 29 of Set 10 | la primavera
# Processing Record 30 of Set 10 | coquimbo
# Processing Record 31 of Set 10 | miraflores
# Processing Record 32 of Set 10 | tostamaa
# City not found. Skipping...
# Processing Record 33 of Set 10 | kuala sungai baru
# Processing Record 34 of Set 10 | monrovia
# Processing Record 35 of Set 10 | matara
# Processing Record 36 of Set 10 | havre-saint-pierre
# Processing Record 37 of Set 10 | mildura
# Processing Record 38 of Set 10 | taltal
# Processing Record 39 of Set 10 | makokou
# Processing Record 40 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 41 of Set 10 | touros
# Processing Record 42 of Set 10 | outjo
# Processing Record 43 of Set 10 | bandarbeyla
# Processing Record 44 of Set 10 | ibra
# Processing Record 45 of Set 10 | mount isa
# Processing Record 46 of Set 10 | port hedland
# Processing Record 47 of Set 10 | tonj
# Processing Record 48 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 10 | lawrenceburg
# Processing Record 50 of Set 10 | liaocheng
# Processing Record 1 of Set 11 | yar-sale
# Processing Record 2 of Set 11 | ballina
# Processing Record 3 of Set 11 | monterey
# Processing Record 4 of Set 11 | pervomayskiy
# Processing Record 5 of Set 11 | chara
# Processing Record 6 of Set 11 | taoudenni
# Processing Record 7 of Set 11 | manicore
# Processing Record 8 of Set 11 | sabang
# Processing Record 9 of Set 11 | yarada
# Processing Record 10 of Set 11 | lundamo
# Processing Record 11 of Set 11 | almaty
# Processing Record 12 of Set 11 | alberton
# Processing Record 13 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 14 of Set 11 | frunze
# Processing Record 15 of Set 11 | riyadh
# Processing Record 16 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 11 | kachug
# Processing Record 18 of Set 11 | eskisehir
# Processing Record 19 of Set 11 | leshukonskoye
# Processing Record 20 of Set 11 | sabzevar
# Processing Record 21 of Set 11 | almaznyy
# Processing Record 22 of Set 11 | olinda
# Processing Record 23 of Set 11 | lata
# Processing Record 24 of Set 11 | terenga
# City not found. Skipping...
# Processing Record 25 of Set 11 | sao filipe
# Processing Record 26 of Set 11 | zhanaozen
# Processing Record 27 of Set 11 | duki
# Processing Record 28 of Set 11 | hailar
# Processing Record 29 of Set 11 | irbil
# Processing Record 30 of Set 11 | ayr
# Processing Record 31 of Set 11 | tiznit
# Processing Record 32 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 11 | tatarsk
# Processing Record 34 of Set 11 | asau
# Processing Record 35 of Set 11 | elat
# Processing Record 36 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 37 of Set 11 | arlit
# Processing Record 38 of Set 11 | zapolyarnyy
# Processing Record 39 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 11 | acapulco
# Processing Record 41 of Set 11 | gurupa
# Processing Record 42 of Set 11 | rexburg
# Processing Record 43 of Set 11 | diego de almagro
# Processing Record 44 of Set 11 | pangody
# Processing Record 45 of Set 11 | mathathane
# Processing Record 46 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 11 | savannah bight
# Processing Record 48 of Set 11 | mincivan
# Processing Record 49 of Set 11 | surgut
# Processing Record 50 of Set 11 | samarai
# Processing Record 1 of Set 12 | loreto
# Processing Record 2 of Set 12 | kudahuvadhoo
# Processing Record 3 of Set 12 | nouakchott
# Processing Record 4 of Set 12 | saint-ambroise
# Processing Record 5 of Set 12 | nemuro
# Processing Record 6 of Set 12 | mogadishu
# Processing Record 7 of Set 12 | floro
# Processing Record 8 of Set 12 | salinas
# Processing Record 9 of Set 12 | antsohihy
# Processing Record 10 of Set 12 | kysyl-syr
# Processing Record 11 of Set 12 | herne bay
# Processing Record 12 of Set 12 | saint anthony
# Processing Record 13 of Set 12 | khomeynishahr
# City not found. Skipping...
# Processing Record 14 of Set 12 | bandar-e lengeh
# Processing Record 15 of Set 12 | baker city
# Processing Record 16 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 12 | ankazoabo
# Processing Record 18 of Set 12 | tromso
# Processing Record 19 of Set 12 | marica
# Processing Record 20 of Set 12 | itarema
# Processing Record 21 of Set 12 | ontario
# Processing Record 22 of Set 12 | dodge city
# Processing Record 23 of Set 12 | ayagoz
# Processing Record 24 of Set 12 | prince rupert
# Processing Record 25 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 26 of Set 12 | hammerfest
# Processing Record 27 of Set 12 | sterling
# Processing Record 28 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 12 | sao joaquim
# Processing Record 30 of Set 12 | kununurra
# Processing Record 31 of Set 12 | kristiinankaupunki
# Processing Record 32 of Set 12 | izhma
# Processing Record 33 of Set 12 | hualmay
# Processing Record 34 of Set 12 | joensuu
# Processing Record 35 of Set 12 | nabire
# Processing Record 36 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 12 | lalmohan
# Processing Record 38 of Set 12 | kiama
# Processing Record 39 of Set 12 | washington
# Processing Record 40 of Set 12 | verkhnetulomskiy
# Processing Record 41 of Set 12 | tucuma
# Processing Record 42 of Set 12 | rath
# Processing Record 43 of Set 12 | taclobo
# Processing Record 44 of Set 12 | paso de carrasco
# Processing Record 45 of Set 12 | torokszentmiklos
# Processing Record 46 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 47 of Set 12 | strezhevoy
# Processing Record 48 of Set 12 | vigia
# Processing Record 49 of Set 12 | kuhestan
# City not found. Skipping...
# Processing Record 50 of Set 12 | gorontalo
# Processing Record 1 of Set 13 | tessalit
# Processing Record 2 of Set 13 | demba
# Processing Record 3 of Set 13 | metro
# Processing Record 4 of Set 13 | fare
# Processing Record 5 of Set 13 | roald
# Processing Record 6 of Set 13 | karasburg
# Processing Record 7 of Set 13 | estelle
# Processing Record 8 of Set 13 | port hardy
# Processing Record 9 of Set 13 | kloulklubed
# Processing Record 10 of Set 13 | kailua
# Processing Record 11 of Set 13 | lixourion
# Processing Record 12 of Set 13 | pangnirtung
# Processing Record 13 of Set 13 | eluru
# Processing Record 14 of Set 13 | miramar
# Processing Record 15 of Set 13 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 16 of Set 13 | yantal
# Processing Record 17 of Set 13 | valparaiso
# Processing Record 18 of Set 13 | rincon
# Processing Record 19 of Set 13 | izazi
# Processing Record 20 of Set 13 | dongsheng
# Processing Record 21 of Set 13 | oktyabrskoye
# Processing Record 22 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 23 of Set 13 | soligalich
# Processing Record 24 of Set 13 | coolum beach
# Processing Record 25 of Set 13 | lasa
# Processing Record 26 of Set 13 | salalah
# Processing Record 27 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 28 of Set 13 | takoradi
# Processing Record 29 of Set 13 | unai
# Processing Record 30 of Set 13 | manjacaze
# Processing Record 31 of Set 13 | calmar
# Processing Record 32 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 13 | biloela
# Processing Record 34 of Set 13 | ossora
# Processing Record 35 of Set 13 | madimba
# Processing Record 36 of Set 13 | ulenje
# Processing Record 37 of Set 13 | banda aceh
# Processing Record 38 of Set 13 | hobyo
# Processing Record 39 of Set 13 | moron
# Processing Record 40 of Set 13 | mnogovershinnyy
# Processing Record 41 of Set 13 | veydelevka
# Processing Record 42 of Set 13 | tracy
# Processing Record 43 of Set 13 | amga
# Processing Record 44 of Set 13 | kupang
# Processing Record 45 of Set 13 | lerwick
# Processing Record 46 of Set 13 | pedasi
# Processing Record 47 of Set 13 | ozernovskiy
# Processing Record 48 of Set 13 | canon city
# Processing Record 49 of Set 13 | igrim
# Processing Record 50 of Set 13 | churapcha
# Processing Record 1 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 14 | peniche
# Processing Record 3 of Set 14 | xinyu
# Processing Record 4 of Set 14 | tabou
# Processing Record 5 of Set 14 | pokhara
# Processing Record 6 of Set 14 | roebourne
# Processing Record 7 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 14 | aksarka
# Processing Record 9 of Set 14 | verkhoyansk
# Processing Record 10 of Set 14 | balaipungut
# Processing Record 11 of Set 14 | rendsburg
# Processing Record 12 of Set 14 | breznik
# Processing Record 13 of Set 14 | quatre cocos
# Processing Record 14 of Set 14 | maltahohe
# Processing Record 15 of Set 14 | mokhsogollokh
# Processing Record 16 of Set 14 | along
# Processing Record 17 of Set 14 | payo
# Processing Record 18 of Set 14 | altay
# Processing Record 19 of Set 14 | kajaani
# Processing Record 20 of Set 14 | balkhash
# Processing Record 21 of Set 14 | santa rosa
# Processing Record 22 of Set 14 | sao desiderio
# Processing Record 23 of Set 14 | emerald
# Processing Record 24 of Set 14 | palmas de monte alto
# Processing Record 25 of Set 14 | lufilufi
# Processing Record 26 of Set 14 | kananga
# Processing Record 27 of Set 14 | winton
# Processing Record 28 of Set 14 | voi
# Processing Record 29 of Set 14 | somers point
# Processing Record 30 of Set 14 | gimli
# Processing Record 31 of Set 14 | catamarca
# Processing Record 32 of Set 14 | kembolcha
# Processing Record 33 of Set 14 | tete
# Processing Record 34 of Set 14 | pacific grove
# Processing Record 35 of Set 14 | soyo
# Processing Record 36 of Set 14 | qaqortoq
# Processing Record 37 of Set 14 | harper
# Processing Record 38 of Set 14 | macusani
# Processing Record 39 of Set 14 | sorong
# Processing Record 40 of Set 14 | belem de sao francisco
# Processing Record 41 of Set 14 | hashtrud
# Processing Record 42 of Set 14 | bogovarovo
# Processing Record 43 of Set 14 | rakhya
# City not found. Skipping...
# Processing Record 44 of Set 14 | acarau
# Processing Record 45 of Set 14 | borba
# Processing Record 46 of Set 14 | salekhard
# Processing Record 47 of Set 14 | batticaloa
# Processing Record 48 of Set 14 | mayumba
# Processing Record 49 of Set 14 | poum
# Processing Record 50 of Set 14 | santa fe
# Processing Record 1 of Set 15 | kintampo
# Processing Record 2 of Set 15 | fairbanks
# Processing Record 3 of Set 15 | ust-nera
# Processing Record 4 of Set 15 | marshall
# Processing Record 5 of Set 15 | asha
# Processing Record 6 of Set 15 | diebougou
# Processing Record 7 of Set 15 | san francisco
# Processing Record 8 of Set 15 | shahrud
# Processing Record 9 of Set 15 | talaya
# Processing Record 10 of Set 15 | redlands
# Processing Record 11 of Set 15 | berlevag
# Processing Record 12 of Set 15 | teneguiban
# City not found. Skipping...
# Processing Record 13 of Set 15 | vostok
# Processing Record 14 of Set 15 | igarape-miri
# City not found. Skipping...
# Processing Record 15 of Set 15 | santiago del estero
# Processing Record 16 of Set 15 | lenger
# Processing Record 17 of Set 15 | general luna
# Processing Record 18 of Set 15 | mountain home
# Processing Record 19 of Set 15 | barcelos
# Processing Record 20 of Set 15 | rio grande
# Processing Record 21 of Set 15 | aykhal
# Processing Record 22 of Set 15 | karasuk
# Processing Record 23 of Set 15 | trairi
# Processing Record 24 of Set 15 | ludvika
# Processing Record 25 of Set 15 | kalmunai
# Processing Record 26 of Set 15 | lakes entrance
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kodiak      US  57.7900 -152.4072     38.71        87         100
# 1  Bambous Virieux      MU -20.3428   57.7575     79.21        94          75
# 2        Geraldton      AU -28.7667  114.6000    108.01         9           0
# 3           Albany      US  42.6001  -73.9662     44.80        85         100
# 4           Barrow      US  71.2906 -156.7887    -23.78        76           0
# 5       San Angelo      US  31.4638 -100.4370     25.02        89         100
# 6           Faanui      PF -16.4833 -151.7500     81.23        77          10
# 7       Lavrentiya      RU  65.5833 -171.0000      3.09        60           1
# 8     Grootfontein      NA -19.5667   18.1167     67.57        53           8
# 9  Arraial Do Cabo      BR -22.9661  -42.0278     74.91        88          98
#
#    Wind Speed Current Description
# 0       10.36       moderate rain
# 1       27.63         shower rain
# 2        5.75           clear sky
# 3        3.22     overcast clouds
# 4        6.91           clear sky
# 5        3.00                mist
# 6       19.71           clear sky
# 7       24.83           clear sky
# 8        7.81           clear sky
# 9        3.91     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
